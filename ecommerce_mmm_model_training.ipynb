# %% [markdown]
# ## Step 1: Import & Load the Data

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Load the main dataset
df = pd.read_csv("compressed_data.csv.gz",                 
  compression="gzip")  
df
# Out:
#                        MMM_TIMESERIES_ID                   ORGANISATION_ID  \
# 0       596eef7c71f933d820d0e485935d0e8f  04769dac8b828ec7a85676d9e2bffe6f
# 1       596eef7c71f933d820d0e485935d0e8f  04769dac8b828ec7a85676d9e2bffe6f
# 2       596eef7c71f933d820d0e485935d0e8f  04769dac8b828ec7a85676d9e2bffe6f
# 3       596eef7c71f933d820d0e485935d0e8f  04769dac8b828ec7a85676d9e2bffe6f
# 4       596eef7c71f933d820d0e485935d0e8f  04769dac8b828ec7a85676d9e2bffe6f
# ...                                  ...                               ...
# 132754  21ae5756595080e735f52426db421505  ff5c2c32d7f1c21594c518fc6a6d4fce
# 132755  21ae5756595080e735f52426db421505  ff5c2c32d7f1c21594c518fc6a6d4fce
# 132756  21ae5756595080e735f52426db421505  ff5c2c32d7f1c21594c518fc6a6d4fce
# 132757  21ae5756595080e735f52426db421505  ff5c2c32d7f1c21594c518fc6a6d4fce
# 132758  21ae5756595080e735f52426db421505  ff5c2c32d7f1c21594c518fc6a6d4fce
#
#        ORGANISATION_VERTICAL ORGANISATION_SUBVERTICAL  \
# 0           Beauty & Fitness                Hair Care
# 1           Beauty & Fitness                Hair Care
# 2           Beauty & Fitness                Hair Care
# 3           Beauty & Fitness                Hair Care
# 4           Beauty & Fitness                Hair Care
# ...                      ...                      ...
# 132754               Apparel                    Other
# 132755               Apparel                    Other
# 132756               Apparel                    Other
# 132757               Apparel                    Other
# 132758               Apparel                    Other
#
#        ORGANISATION_MARKETING_SOURCES ORGANISATION_PRIMARY_TERRITORY_NAME  \
# 0                        Google, Meta                                  US
# 1                        Google, Meta                                  US
# 2                        Google, Meta                                  US
# 3                        Google, Meta                                  US
# 4                        Google, Meta                                  US
# ...                               ...                                 ...
# 132754                   Google, Meta                                  US
# 132755                   Google, Meta                                  US
# 132756                   Google, Meta                                  US
# 132757                   Google, Meta                                  US
# 132758                   Google, Meta                                  US
#
#          TERRITORY_NAME    DATE_DAY CURRENCY_CODE  FIRST_PURCHASES  ...  \
# 0       All Territories  29-07-2022           USD               22  ...
# 1       All Territories  30-07-2022           USD               14  ...
# 2       All Territories  31-07-2022           USD               31  ...
# 3       All Territories  01-08-2022           USD               18  ...
# 4       All Territories  02-08-2022           USD               23  ...
# ...                 ...         ...           ...              ...  ...
# 132754  All Territories  15-05-2024           USD               14  ...
# 132755  All Territories  16-05-2024           USD               12  ...
# 132756  All Territories  17-05-2024           USD                7  ...
# 132757  All Territories  18-05-2024           USD               14  ...
# 132758  All Territories  19-05-2024           USD               10  ...
#
#         META_FACEBOOK_IMPRESSIONS  META_INSTAGRAM_IMPRESSIONS  \
# 0                         18997.0                         NaN
# 1                         20188.0                         NaN
# 2                         24718.0                         NaN
# 3                         25076.0                         NaN
# 4                         22688.0                         NaN
# ...                           ...                         ...
# 132754                    50550.0                         NaN
# 132755                    51024.0                         NaN
# 132756                    41637.0                         NaN
# 132757                    37661.0                         NaN
# 132758                    34170.0                         NaN
#
#         META_OTHER_IMPRESSIONS  TIKTOK_IMPRESSIONS  DIRECT_CLICKS  \
# 0                          NaN                 NaN          139.0
# 1                          NaN                 NaN          209.0
# 2                          NaN                 NaN          262.0
# 3                          NaN                 NaN          247.0
# 4                          NaN                 NaN          255.0
# ...                        ...                 ...            ...
# 132754                     NaN                 NaN          294.0
# 132755                     NaN                 NaN          206.0
# 132756                     NaN                 NaN          216.0
# 132757                     NaN                 NaN          951.0
# 132758                     NaN                 NaN          401.0
#
#         BRANDED_SEARCH_CLICKS  ORGANIC_SEARCH_CLICKS  EMAIL_CLICKS  \
# 0                         NaN                  300.0           1.0
# 1                         NaN                  442.0           8.0
# 2                         NaN                  427.0         631.0
# 3                         NaN                  400.0         117.0
# 4                         NaN                  425.0          37.0
# ...                       ...                    ...           ...
# 132754                  204.0                  234.0        1624.0
# 132755                  212.0                  209.0         225.0
# 132756                  186.0                  213.0          88.0
# 132757                  169.0                  190.0         167.0
# 132758                   83.0                  178.0          56.0
#
#         REFERRAL_CLICKS  ALL_OTHER_CLICKS
# 0                  61.0              40.0
# 1                 110.0              62.0
# 2                 108.0              65.0
# 3                 125.0              68.0
# 4                 146.0              65.0
# ...                 ...               ...
# 132754             54.0             380.0
# 132755             48.0             335.0
# 132756             40.0             706.0
# 132757             37.0             366.0
# 132758             41.0             933.0
#
# [132759 rows x 50 columns]

# %%
# Quick check
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132759 entries, 0 to 132758
# Data columns (total 50 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   MMM_TIMESERIES_ID                    132759 non-null  object
#  1   ORGANISATION_ID                      132759 non-null  object
#  2   ORGANISATION_VERTICAL                124649 non-null  object
#  3   ORGANISATION_SUBVERTICAL             124649 non-null  object
#  4   ORGANISATION_MARKETING_SOURCES       132759 non-null  object
#  5   ORGANISATION_PRIMARY_TERRITORY_NAME  132759 non-null  object
#  6   TERRITORY_NAME                       132759 non-null  object
#  7   DATE_DAY                             132759 non-null  object
#  8   CURRENCY_CODE                        132759 non-null  object
#  9   FIRST_PURCHASES                      132759 non-null  int64
#  10  FIRST_PURCHASES_UNITS                132759 non-null  int64
#  11  FIRST_PURCHASES_ORIGINAL_PRICE       132759 non-null  float64
#  12  FIRST_PURCHASES_GROSS_DISCOUNT       132759 non-null  float64
#  13  ALL_PURCHASES                        132759 non-null  int64
#  14  ALL_PURCHASES_UNITS                  132759 non-null  int64
#  15  ALL_PURCHASES_ORIGINAL_PRICE         132759 non-null  float64
#  16  ALL_PURCHASES_GROSS_DISCOUNT         132759 non-null  float64
#  17  GOOGLE_PAID_SEARCH_SPEND             96637 non-null   float64
#  18  GOOGLE_SHOPPING_SPEND                78980 non-null   float64
#  19  GOOGLE_PMAX_SPEND                    61126 non-null   float64
#  20  GOOGLE_DISPLAY_SPEND                 18746 non-null   float64
#  21  GOOGLE_VIDEO_SPEND                   7628 non-null    float64
#  22  META_FACEBOOK_SPEND                  80112 non-null   float64
#  23  META_INSTAGRAM_SPEND                 26817 non-null   float64
#  24  META_OTHER_SPEND                     23545 non-null   float64
#  25  TIKTOK_SPEND                         3462 non-null    float64
#  26  GOOGLE_PAID_SEARCH_CLICKS            96637 non-null   float64
#  27  GOOGLE_SHOPPING_CLICKS               78980 non-null   float64
#  28  GOOGLE_PMAX_CLICKS                   61126 non-null   float64
#  29  GOOGLE_DISPLAY_CLICKS                18746 non-null   float64
#  30  GOOGLE_VIDEO_CLICKS                  7628 non-null    float64
#  31  META_FACEBOOK_CLICKS                 80112 non-null   float64
#  32  META_INSTAGRAM_CLICKS                26817 non-null   float64
#  33  META_OTHER_CLICKS                    23545 non-null   float64
#  34  TIKTOK_CLICKS                        3462 non-null    float64
#  35  GOOGLE_PAID_SEARCH_IMPRESSIONS       96637 non-null   float64
#  36  GOOGLE_SHOPPING_IMPRESSIONS          78980 non-null   float64
#  37  GOOGLE_PMAX_IMPRESSIONS              61126 non-null   float64
#  38  GOOGLE_DISPLAY_IMPRESSIONS           18746 non-null   float64
#  39  GOOGLE_VIDEO_IMPRESSIONS             7628 non-null    float64
#  40  META_FACEBOOK_IMPRESSIONS            80112 non-null   float64
#  41  META_INSTAGRAM_IMPRESSIONS           26817 non-null   float64
#  42  META_OTHER_IMPRESSIONS               23545 non-null   float64
#  43  TIKTOK_IMPRESSIONS                   3462 non-null    float64
#  44  DIRECT_CLICKS                        98541 non-null   float64
#  45  BRANDED_SEARCH_CLICKS                88825 non-null   float64
#  46  ORGANIC_SEARCH_CLICKS                122702 non-null  float64
#  47  EMAIL_CLICKS                         118663 non-null  float64
#  48  REFERRAL_CLICKS                      121737 non-null  float64
#  49  ALL_OTHER_CLICKS                     121778 non-null  float64
# dtypes: float64(37), int64(4), object(9)
# memory usage: 50.6+ MB

# %%
df.head()
# Out:
#                   MMM_TIMESERIES_ID                   ORGANISATION_ID  \
# 0  596eef7c71f933d820d0e485935d0e8f  04769dac8b828ec7a85676d9e2bffe6f
# 1  596eef7c71f933d820d0e485935d0e8f  04769dac8b828ec7a85676d9e2bffe6f
# 2  596eef7c71f933d820d0e485935d0e8f  04769dac8b828ec7a85676d9e2bffe6f
# 3  596eef7c71f933d820d0e485935d0e8f  04769dac8b828ec7a85676d9e2bffe6f
# 4  596eef7c71f933d820d0e485935d0e8f  04769dac8b828ec7a85676d9e2bffe6f
#
#   ORGANISATION_VERTICAL ORGANISATION_SUBVERTICAL  \
# 0      Beauty & Fitness                Hair Care
# 1      Beauty & Fitness                Hair Care
# 2      Beauty & Fitness                Hair Care
# 3      Beauty & Fitness                Hair Care
# 4      Beauty & Fitness                Hair Care
#
#   ORGANISATION_MARKETING_SOURCES ORGANISATION_PRIMARY_TERRITORY_NAME  \
# 0                   Google, Meta                                  US
# 1                   Google, Meta                                  US
# 2                   Google, Meta                                  US
# 3                   Google, Meta                                  US
# 4                   Google, Meta                                  US
#
#     TERRITORY_NAME    DATE_DAY CURRENCY_CODE  FIRST_PURCHASES  ...  \
# 0  All Territories  29-07-2022           USD               22  ...
# 1  All Territories  30-07-2022           USD               14  ...
# 2  All Territories  31-07-2022           USD               31  ...
# 3  All Territories  01-08-2022           USD               18  ...
# 4  All Territories  02-08-2022           USD               23  ...
#
#    META_FACEBOOK_IMPRESSIONS  META_INSTAGRAM_IMPRESSIONS  \
# 0                    18997.0                         NaN
# 1                    20188.0                         NaN
# 2                    24718.0                         NaN
# 3                    25076.0                         NaN
# 4                    22688.0                         NaN
#
#    META_OTHER_IMPRESSIONS  TIKTOK_IMPRESSIONS  DIRECT_CLICKS  \
# 0                     NaN                 NaN          139.0
# 1                     NaN                 NaN          209.0
# 2                     NaN                 NaN          262.0
# 3                     NaN                 NaN          247.0
# 4                     NaN                 NaN          255.0
#
#    BRANDED_SEARCH_CLICKS  ORGANIC_SEARCH_CLICKS  EMAIL_CLICKS  \
# 0                    NaN                  300.0           1.0
# 1                    NaN                  442.0           8.0
# 2                    NaN                  427.0         631.0
# 3                    NaN                  400.0         117.0
# 4                    NaN                  425.0          37.0
#
#    REFERRAL_CLICKS  ALL_OTHER_CLICKS
# 0             61.0              40.0
# 1            110.0              62.0
# 2            108.0              65.0
# 3            125.0              68.0
# 4            146.0              65.0
#
# [5 rows x 50 columns]

# %% [markdown]
# ## Step 2: Missing Value Treatment

# %%
# Check null values summary (optional to visualize)
print(df.isnull().sum().sort_values(ascending=False))
# Out:
# TIKTOK_CLICKS                          129297
# TIKTOK_SPEND                           129297
# TIKTOK_IMPRESSIONS                     129297
# GOOGLE_VIDEO_SPEND                     125131
# GOOGLE_VIDEO_IMPRESSIONS               125131
# GOOGLE_VIDEO_CLICKS                    125131
# GOOGLE_DISPLAY_SPEND                   114013
# GOOGLE_DISPLAY_CLICKS                  114013
# GOOGLE_DISPLAY_IMPRESSIONS             114013
# META_OTHER_CLICKS                      109214
# META_OTHER_IMPRESSIONS                 109214
# META_OTHER_SPEND                       109214
# META_INSTAGRAM_SPEND                   105942
# META_INSTAGRAM_CLICKS                  105942
# META_INSTAGRAM_IMPRESSIONS             105942
# GOOGLE_PMAX_CLICKS                      71633
# GOOGLE_PMAX_SPEND                       71633
# GOOGLE_PMAX_IMPRESSIONS                 71633
# GOOGLE_SHOPPING_IMPRESSIONS             53779
# GOOGLE_SHOPPING_CLICKS                  53779
# GOOGLE_SHOPPING_SPEND                   53779
# META_FACEBOOK_IMPRESSIONS               52647
# META_FACEBOOK_SPEND                     52647
# META_FACEBOOK_CLICKS                    52647
# BRANDED_SEARCH_CLICKS                   43934
# GOOGLE_PAID_SEARCH_SPEND                36122
# GOOGLE_PAID_SEARCH_IMPRESSIONS          36122
# GOOGLE_PAID_SEARCH_CLICKS               36122
# DIRECT_CLICKS                           34218
# EMAIL_CLICKS                            14096
# REFERRAL_CLICKS                         11022
# ALL_OTHER_CLICKS                        10981
# ORGANIC_SEARCH_CLICKS                   10057
# ORGANISATION_VERTICAL                    8110
# ORGANISATION_SUBVERTICAL                 8110
# ALL_PURCHASES_GROSS_DISCOUNT                0
# ALL_PURCHASES_UNITS                         0
# ALL_PURCHASES_ORIGINAL_PRICE                0
# FIRST_PURCHASES_ORIGINAL_PRICE              0
# FIRST_PURCHASES_GROSS_DISCOUNT              0
# FIRST_PURCHASES_UNITS                       0
# ALL_PURCHASES                               0
# ORGANISATION_PRIMARY_TERRITORY_NAME         0
# CURRENCY_CODE                               0
# DATE_DAY                                    0
# TERRITORY_NAME                              0
# ORGANISATION_MARKETING_SOURCES              0
# ORGANISATION_ID                             0
# MMM_TIMESERIES_ID                           0
# FIRST_PURCHASES                             0
# dtype: int64

# %%
# Drop irrelevant columns
drop_cols = [
    'TIKTOK_SPEND', 'TIKTOK_CLICKS', 'TIKTOK_IMPRESSIONS',
    'GOOGLE_VIDEO_SPEND', 'GOOGLE_VIDEO_CLICKS', 'GOOGLE_VIDEO_IMPRESSIONS',
    'GOOGLE_DISPLAY_SPEND', 'GOOGLE_DISPLAY_CLICKS', 'GOOGLE_DISPLAY_IMPRESSIONS',
    'META_OTHER_SPEND', 'META_OTHER_CLICKS', 'META_OTHER_IMPRESSIONS'
]
df.drop(columns=drop_cols, inplace=True)

# %%
# Fill missing values with zero
fill_zero_cols = [
    'GOOGLE_PAID_SEARCH_SPEND', 'GOOGLE_PAID_SEARCH_CLICKS', 'GOOGLE_PAID_SEARCH_IMPRESSIONS',
    'GOOGLE_SHOPPING_SPEND', 'GOOGLE_SHOPPING_CLICKS', 'GOOGLE_SHOPPING_IMPRESSIONS',
    'GOOGLE_PMAX_SPEND', 'GOOGLE_PMAX_CLICKS', 'GOOGLE_PMAX_IMPRESSIONS',
    'META_FACEBOOK_SPEND', 'META_FACEBOOK_CLICKS', 'META_FACEBOOK_IMPRESSIONS',
    'META_INSTAGRAM_SPEND', 'META_INSTAGRAM_CLICKS', 'META_INSTAGRAM_IMPRESSIONS',
    'BRANDED_SEARCH_CLICKS', 'DIRECT_CLICKS', 'EMAIL_CLICKS',
    'REFERRAL_CLICKS', 'ALL_OTHER_CLICKS', 'ORGANIC_SEARCH_CLICKS'
]
df[fill_zero_cols] = df[fill_zero_cols].fillna(0)

# %%
print("\n Missing values after cleaning:")
df.isnull().sum()
# Out:
#  Missing values after cleaning:
# MMM_TIMESERIES_ID                         0
# ORGANISATION_ID                           0
# ORGANISATION_VERTICAL                  8110
# ORGANISATION_SUBVERTICAL               8110
# ORGANISATION_MARKETING_SOURCES            0
# ORGANISATION_PRIMARY_TERRITORY_NAME       0
# TERRITORY_NAME                            0
# DATE_DAY                                  0
# CURRENCY_CODE                             0
# FIRST_PURCHASES                           0
# FIRST_PURCHASES_UNITS                     0
# FIRST_PURCHASES_ORIGINAL_PRICE            0
# FIRST_PURCHASES_GROSS_DISCOUNT            0
# ALL_PURCHASES                             0
# ALL_PURCHASES_UNITS                       0
# ALL_PURCHASES_ORIGINAL_PRICE              0
# ALL_PURCHASES_GROSS_DISCOUNT              0
# GOOGLE_PAID_SEARCH_SPEND                  0
# GOOGLE_SHOPPING_SPEND                     0
# GOOGLE_PMAX_SPEND                         0
# META_FACEBOOK_SPEND                       0
# META_INSTAGRAM_SPEND                      0
# GOOGLE_PAID_SEARCH_CLICKS                 0
# GOOGLE_SHOPPING_CLICKS                    0
# GOOGLE_PMAX_CLICKS                        0
# META_FACEBOOK_CLICKS                      0
# META_INSTAGRAM_CLICKS                     0
# GOOGLE_PAID_SEARCH_IMPRESSIONS            0
# GOOGLE_SHOPPING_IMPRESSIONS               0
# GOOGLE_PMAX_IMPRESSIONS                   0
# META_FACEBOOK_IMPRESSIONS                 0
# META_INSTAGRAM_IMPRESSIONS                0
# DIRECT_CLICKS                             0
# BRANDED_SEARCH_CLICKS                     0
# ORGANIC_SEARCH_CLICKS                     0
# EMAIL_CLICKS                              0
# REFERRAL_CLICKS                           0
# ALL_OTHER_CLICKS                          0
# dtype: int64

# %%
optional_meta_cols = ['MMM_TIMESERIES_ID', 'ORGANISATION_VERTICAL', 'ORGANISATION_SUBVERTICAL']
df.drop(columns=optional_meta_cols, inplace=True)

# %%
df.isnull().sum()
# Out:
# ORGANISATION_ID                        0
# ORGANISATION_MARKETING_SOURCES         0
# ORGANISATION_PRIMARY_TERRITORY_NAME    0
# TERRITORY_NAME                         0
# DATE_DAY                               0
# CURRENCY_CODE                          0
# FIRST_PURCHASES                        0
# FIRST_PURCHASES_UNITS                  0
# FIRST_PURCHASES_ORIGINAL_PRICE         0
# FIRST_PURCHASES_GROSS_DISCOUNT         0
# ALL_PURCHASES                          0
# ALL_PURCHASES_UNITS                    0
# ALL_PURCHASES_ORIGINAL_PRICE           0
# ALL_PURCHASES_GROSS_DISCOUNT           0
# GOOGLE_PAID_SEARCH_SPEND               0
# GOOGLE_SHOPPING_SPEND                  0
# GOOGLE_PMAX_SPEND                      0
# META_FACEBOOK_SPEND                    0
# META_INSTAGRAM_SPEND                   0
# GOOGLE_PAID_SEARCH_CLICKS              0
# GOOGLE_SHOPPING_CLICKS                 0
# GOOGLE_PMAX_CLICKS                     0
# META_FACEBOOK_CLICKS                   0
# META_INSTAGRAM_CLICKS                  0
# GOOGLE_PAID_SEARCH_IMPRESSIONS         0
# GOOGLE_SHOPPING_IMPRESSIONS            0
# GOOGLE_PMAX_IMPRESSIONS                0
# META_FACEBOOK_IMPRESSIONS              0
# META_INSTAGRAM_IMPRESSIONS             0
# DIRECT_CLICKS                          0
# BRANDED_SEARCH_CLICKS                  0
# ORGANIC_SEARCH_CLICKS                  0
# EMAIL_CLICKS                           0
# REFERRAL_CLICKS                        0
# ALL_OTHER_CLICKS                       0
# dtype: int64

# %%
df
# Out:
#                          ORGANISATION_ID ORGANISATION_MARKETING_SOURCES  \
# 0       04769dac8b828ec7a85676d9e2bffe6f                   Google, Meta
# 1       04769dac8b828ec7a85676d9e2bffe6f                   Google, Meta
# 2       04769dac8b828ec7a85676d9e2bffe6f                   Google, Meta
# 3       04769dac8b828ec7a85676d9e2bffe6f                   Google, Meta
# 4       04769dac8b828ec7a85676d9e2bffe6f                   Google, Meta
# ...                                  ...                            ...
# 132754  ff5c2c32d7f1c21594c518fc6a6d4fce                   Google, Meta
# 132755  ff5c2c32d7f1c21594c518fc6a6d4fce                   Google, Meta
# 132756  ff5c2c32d7f1c21594c518fc6a6d4fce                   Google, Meta
# 132757  ff5c2c32d7f1c21594c518fc6a6d4fce                   Google, Meta
# 132758  ff5c2c32d7f1c21594c518fc6a6d4fce                   Google, Meta
#
#        ORGANISATION_PRIMARY_TERRITORY_NAME   TERRITORY_NAME    DATE_DAY  \
# 0                                       US  All Territories  29-07-2022
# 1                                       US  All Territories  30-07-2022
# 2                                       US  All Territories  31-07-2022
# 3                                       US  All Territories  01-08-2022
# 4                                       US  All Territories  02-08-2022
# ...                                    ...              ...         ...
# 132754                                  US  All Territories  15-05-2024
# 132755                                  US  All Territories  16-05-2024
# 132756                                  US  All Territories  17-05-2024
# 132757                                  US  All Territories  18-05-2024
# 132758                                  US  All Territories  19-05-2024
#
#        CURRENCY_CODE  FIRST_PURCHASES  FIRST_PURCHASES_UNITS  \
# 0                USD               22                     27
# 1                USD               14                     21
# 2                USD               31                     39
# 3                USD               18                     30
# 4                USD               23                     27
# ...              ...              ...                    ...
# 132754           USD               14                    102
# 132755           USD               12                     61
# 132756           USD                7                     45
# 132757           USD               14                    113
# 132758           USD               10                     83
#
#         FIRST_PURCHASES_ORIGINAL_PRICE  FIRST_PURCHASES_GROSS_DISCOUNT  ...  \
# 0                          3837.980834                      632.595555  ...
# 1                          2747.998631                      443.996523  ...
# 2                          4567.998818                     1185.197966  ...
# 3                          2878.982385                      696.519993  ...
# 4                          3107.993669                      627.097427  ...
# ...                                ...                             ...  ...
# 132754                     5117.501854                      140.000000  ...
# 132755                     4015.000000                      250.510000  ...
# 132756                     1132.500000                        5.000000  ...
# 132757                     3997.500000                       50.500000  ...
# 132758                     3493.752792                      140.250000  ...
#
#         GOOGLE_SHOPPING_IMPRESSIONS  GOOGLE_PMAX_IMPRESSIONS  \
# 0                               0.0                  31907.0
# 1                               0.0                  44483.0
# 2                               0.0                  58173.0
# 3                               0.0                  55559.0
# 4                               0.0                  47854.0
# ...                             ...                      ...
# 132754                         33.0                  10786.0
# 132755                         11.0                   8274.0
# 132756                          6.0                  14495.0
# 132757                          0.0                  31355.0
# 132758                          0.0                  39773.0
#
#         META_FACEBOOK_IMPRESSIONS  META_INSTAGRAM_IMPRESSIONS  DIRECT_CLICKS  \
# 0                         18997.0                         0.0          139.0
# 1                         20188.0                         0.0          209.0
# 2                         24718.0                         0.0          262.0
# 3                         25076.0                         0.0          247.0
# 4                         22688.0                         0.0          255.0
# ...                           ...                         ...            ...
# 132754                    50550.0                         0.0          294.0
# 132755                    51024.0                         0.0          206.0
# 132756                    41637.0                         0.0          216.0
# 132757                    37661.0                         0.0          951.0
# 132758                    34170.0                         0.0          401.0
#
#         BRANDED_SEARCH_CLICKS  ORGANIC_SEARCH_CLICKS  EMAIL_CLICKS  \
# 0                         0.0                  300.0           1.0
# 1                         0.0                  442.0           8.0
# 2                         0.0                  427.0         631.0
# 3                         0.0                  400.0         117.0
# 4                         0.0                  425.0          37.0
# ...                       ...                    ...           ...
# 132754                  204.0                  234.0        1624.0
# 132755                  212.0                  209.0         225.0
# 132756                  186.0                  213.0          88.0
# 132757                  169.0                  190.0         167.0
# 132758                   83.0                  178.0          56.0
#
#         REFERRAL_CLICKS  ALL_OTHER_CLICKS
# 0                  61.0              40.0
# 1                 110.0              62.0
# 2                 108.0              65.0
# 3                 125.0              68.0
# 4                 146.0              65.0
# ...                 ...               ...
# 132754             54.0             380.0
# 132755             48.0             335.0
# 132756             40.0             706.0
# 132757             37.0             366.0
# 132758             41.0             933.0
#
# [132759 rows x 35 columns]

# %% [markdown]
# ## Step 3: Feature Engineering & Preprocessing

# %% [markdown]
# #### *Convert DATE_DAY to datetime and Create Time Features*

# %%
# Convert DATE_DAY to datetime
df['DATE_DAY'] = pd.to_datetime(df['DATE_DAY'])

# %%
# Sort data by Date
df = df.sort_values('DATE_DAY')

# %%
# Create time features
df['year'] = df['DATE_DAY'].dt.year
df['month'] = df['DATE_DAY'].dt.month
df['week'] = df['DATE_DAY'].dt.isocalendar().week
df['day_of_week'] = df['DATE_DAY'].dt.dayofweek

# %%
plt.figure(figsize=(12,6))
sns.lineplot(data=df, x='DATE_DAY', y='ALL_PURCHASES_ORIGINAL_PRICE')
plt.title("Sales Over Time")
plt.show()

# %% [markdown]
# #### *Create ROI-related features*

# %%
# Create a new column 'revenue'
df['revenue'] = df['ALL_PURCHASES_ORIGINAL_PRICE'] - df['ALL_PURCHASES_GROSS_DISCOUNT']

# %%
df.head()
# Out:
#                         ORGANISATION_ID ORGANISATION_MARKETING_SOURCES  \
# 11211  0d1fc3f1715b0c65776780e7ad8ac7df                         Google
# 11212  0d1fc3f1715b0c65776780e7ad8ac7df                         Google
# 11213  0d1fc3f1715b0c65776780e7ad8ac7df                         Google
# 11214  0d1fc3f1715b0c65776780e7ad8ac7df                         Google
# 11215  0d1fc3f1715b0c65776780e7ad8ac7df                         Google
#
#       ORGANISATION_PRIMARY_TERRITORY_NAME   TERRITORY_NAME   DATE_DAY  \
# 11211                                  UK  All Territories 2019-07-21
# 11212                                  UK  All Territories 2019-07-22
# 11213                                  UK  All Territories 2019-07-23
# 11214                                  UK  All Territories 2019-07-24
# 11215                                  UK  All Territories 2019-07-25
#
#       CURRENCY_CODE  FIRST_PURCHASES  FIRST_PURCHASES_UNITS  \
# 11211           GBP               18                     26
# 11212           GBP               25                     33
# 11213           GBP               19                     24
# 11214           GBP               21                     26
# 11215           GBP               17                     19
#
#        FIRST_PURCHASES_ORIGINAL_PRICE  FIRST_PURCHASES_GROSS_DISCOUNT  ...  \
# 11211                     3207.120432                      233.137508  ...
# 11212                     3038.609452                       84.538390  ...
# 11213                     2388.545073                       15.750041  ...
# 11214                     2898.101824                       57.745678  ...
# 11215                     2228.808889                        5.580983  ...
#
#        BRANDED_SEARCH_CLICKS  ORGANIC_SEARCH_CLICKS  EMAIL_CLICKS  \
# 11211                    0.0                    2.0           3.0
# 11212                    0.0                   16.0           0.0
# 11213                    0.0                    6.0           0.0
# 11214                    0.0                   13.0           4.0
# 11215                    0.0                   34.0           2.0
#
#        REFERRAL_CLICKS  ALL_OTHER_CLICKS  year  month  week  day_of_week  \
# 11211              0.0               2.0  2019      7    29            6
# 11212              0.0              12.0  2019      7    30            0
# 11213              2.0               2.0  2019      7    30            1
# 11214              0.0              10.0  2019      7    30            2
# 11215              9.0               8.0  2019      7    30            3
#
#            revenue
# 11211  3066.336913
# 11212  2954.071062
# 11213  2372.795032
# 11214  2983.466115
# 11215  2223.227906
#
# [5 rows x 40 columns]

# %%
# Calculate Total Spend

df['total_spend'] = (
    df['GOOGLE_PAID_SEARCH_SPEND'] +
    df['GOOGLE_SHOPPING_SPEND'] +
    df['GOOGLE_PMAX_SPEND'] +
    df['META_FACEBOOK_SPEND'] +
    df['META_INSTAGRAM_SPEND']
)

# %%
# Calculate ROI
df['roi'] = df['revenue'] / (df['total_spend'] + 1)  # add 1 to avoid div-by-zero

# %%
df
# Out:
#                          ORGANISATION_ID ORGANISATION_MARKETING_SOURCES  \
# 11211   0d1fc3f1715b0c65776780e7ad8ac7df                         Google
# 11212   0d1fc3f1715b0c65776780e7ad8ac7df                         Google
# 11213   0d1fc3f1715b0c65776780e7ad8ac7df                         Google
# 11214   0d1fc3f1715b0c65776780e7ad8ac7df                         Google
# 11215   0d1fc3f1715b0c65776780e7ad8ac7df                         Google
# ...                                  ...                            ...
# 77644   882ce7e286d66facc66518783e2192c7                   Google, Meta
# 32493   3f4463f3b51fc2056b97766e2373747d                   Google, Meta
# 109456  ba773ebd7ec0a08f1d042187d086ccb4                   Google, Meta
# 69673   7a801df71696ceb035e3503253cb15cf                         Google
# 104128  ba773ebd7ec0a08f1d042187d086ccb4                   Google, Meta
#
#        ORGANISATION_PRIMARY_TERRITORY_NAME   TERRITORY_NAME   DATE_DAY  \
# 11211                                   UK  All Territories 2019-07-21
# 11212                                   UK  All Territories 2019-07-22
# 11213                                   UK  All Territories 2019-07-23
# 11214                                   UK  All Territories 2019-07-24
# 11215                                   UK  All Territories 2019-07-25
# ...                                    ...              ...        ...
# 77644                                   UK            Spain 2024-06-02
# 32493                                   UK  All Territories 2024-06-02
# 109456                                  UK            Italy 2024-06-02
# 69673                            Australia  All Territories 2024-06-02
# 104128                                  UK               UK 2024-06-02
#
#        CURRENCY_CODE  FIRST_PURCHASES  FIRST_PURCHASES_UNITS  \
# 11211            GBP               18                     26
# 11212            GBP               25                     33
# 11213            GBP               19                     24
# 11214            GBP               21                     26
# 11215            GBP               17                     19
# ...              ...              ...                    ...
# 77644            EUR                8                     11
# 32493            GBP               20                    126
# 109456           EUR               23                     32
# 69673            AUD              128                    150
# 104128           GBP              154                    185
#
#         FIRST_PURCHASES_ORIGINAL_PRICE  FIRST_PURCHASES_GROSS_DISCOUNT  ...  \
# 11211                      3207.120432                      233.137508  ...
# 11212                      3038.609452                       84.538390  ...
# 11213                      2388.545073                       15.750041  ...
# 11214                      2898.101824                       57.745678  ...
# 11215                      2228.808889                        5.580983  ...
# ...                                ...                             ...  ...
# 77644                      2583.000000                      176.750000  ...
# 32493                      1291.460000                       55.390000  ...
# 109456                     9362.060000                      532.450000  ...
# 69673                      4136.813557                        0.000000  ...
# 104128                    45110.210000                     3341.550000  ...
#
#         EMAIL_CLICKS  REFERRAL_CLICKS  ALL_OTHER_CLICKS  year  month  week  \
# 11211            3.0              0.0               2.0  2019      7    29
# 11212            0.0              0.0              12.0  2019      7    30
# 11213            0.0              2.0               2.0  2019      7    30
# 11214            4.0              0.0              10.0  2019      7    30
# 11215            2.0              9.0               8.0  2019      7    30
# ...              ...              ...               ...   ...    ...   ...
# 77644           68.0           1074.0              99.0  2024      6    22
# 32493            5.0             14.0             283.0  2024      6    22
# 109456         115.0           1065.0              68.0  2024      6    22
# 69673            0.0              7.0             538.0  2024      6    22
# 104128          56.0           2537.0             286.0  2024      6    22
#
#         day_of_week       revenue  total_spend        roi
# 11211             6   3066.336913    86.953533  34.863147
# 11212             0   2954.071062    87.497234  33.380377
# 11213             1   2372.795032    85.995222  27.275004
# 11214             2   2983.466115    95.609758  30.881623
# 11215             3   2223.227906    73.758269  29.738890
# ...             ...           ...          ...        ...
# 77644             6   2585.850000   412.730000   6.250091
# 32493             6   2385.613089   112.520000  21.014914
# 109456            6  10495.970000   417.090000  25.104571
# 69673             6   4414.813557  2596.965450   1.699335
# 104128            6  52141.660000  4239.140000  12.297155
#
# [132759 rows x 42 columns]

# %%
plt.figure(figsize=(12,8))
sns.lineplot(data=df, x='DATE_DAY', y='roi')
plt.title("ROI Over Time")
plt.show()

# %% [markdown]
# #### *Set the Target Variable and Input Features*

# %%
target = 'revenue'

# %%
features = [
    'GOOGLE_PAID_SEARCH_SPEND', 'GOOGLE_SHOPPING_SPEND',
    'GOOGLE_PMAX_SPEND', 'META_FACEBOOK_SPEND', 'META_INSTAGRAM_SPEND',
    'EMAIL_CLICKS', 'ORGANIC_SEARCH_CLICKS', 'DIRECT_CLICKS',
    'BRANDED_SEARCH_CLICKS', 'year', 'month', 'day_of_week'
]

# %% [markdown]
# ## Step 4: Train-Test Split

# %% [markdown]
# #### Since this is time series data, we will use chronological split

# %%
# Sort by date
df = df.sort_values('DATE_DAY')

# Define cutoff date for time-based split
cutoff_date = '2023-12-31'  # Train on data up to end of 2023

# Train = everything before cutoff
train_df = df[df['DATE_DAY'] <= cutoff_date]

# Test = everything after cutoff
test_df = df[df['DATE_DAY'] > cutoff_date]

# Features and target
X_train = train_df[features]
y_train = train_df['revenue']
X_test = test_df[features]
y_test = test_df['revenue']

# %% [markdown]
# ## Step 5: Model Training

# %%
# Linear Regression model (standard for MMM)

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Step 6: Model Evaluation

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_pred = model.predict(X_test)

print("R² Score:", r2_score(y_test, y_pred))
print("RMSE:", mean_squared_error(y_test, y_pred))
# Out:
# R² Score: 0.7891499083056959
# RMSE: 246748035379.61908

# %% [markdown]
# ## Step 7: Feature Importance

# %% [markdown]
# #### Linear models gives coefficients, which are ROI signals

# %%
importance = pd.DataFrame({
    'feature': features,
    'coefficient': model.coef_
}).sort_values(by='coefficient', ascending=False)

print(importance)
# Out:
#                      feature   coefficient
# 9                       year  19603.649446
# 10                     month   2600.523045
# 0   GOOGLE_PAID_SEARCH_SPEND     86.755994
# 5               EMAIL_CLICKS     80.479507
# 1      GOOGLE_SHOPPING_SPEND     46.873508
# 6      ORGANIC_SEARCH_CLICKS     34.919731
# 4       META_INSTAGRAM_SPEND     14.367582
# 3        META_FACEBOOK_SPEND      7.994609
# 8      BRANDED_SEARCH_CLICKS      5.154363
# 7              DIRECT_CLICKS    -19.450303
# 2          GOOGLE_PMAX_SPEND    -23.379289
# 11               day_of_week  -1347.359433

# %% [markdown]
# ## Step 8: Budget Shift Simulation

# %%
scenario = X_test.copy()

# %%
# Simulate increased Google Ads, decreased TV
scenario['GOOGLE_PAID_SEARCH_SPEND'] *= 1.3  # +30%
# scenario['TV_SPEND'] *= 0.8  # if applicable

y_simulated = model.predict(scenario)

# Compare with actual predicted
change = ((y_simulated.mean() - y_pred.mean()) / y_pred.mean()) * 100
print(f"Simulated change in revenue: {change:.2f}%")
# Out:
# Simulated change in revenue: 4.60%

# %%
plt.figure(figsize=(12,6))
plt.plot(test_df['DATE_DAY'], y_test, label='Actual Revenue')
plt.plot(test_df['DATE_DAY'], y_pred, label='Predicted Revenue')
plt.title("Actual vs Predicted Revenue")
plt.legend()
plt.show()

# %% [markdown]
# ## Step 9: Final Step

# %%
# Save the trained model

import joblib
joblib.dump(model, 'linear_mmm_model.pkl')
# Out:
# ['linear_mmm_model.pkl']

# %%
# Save the features used for training
import json
with open('mmm_model_features.json', 'w') as f:
    json.dump(features, f)
